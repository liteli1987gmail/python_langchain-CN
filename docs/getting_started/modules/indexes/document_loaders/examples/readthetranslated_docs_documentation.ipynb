# %% [markdown]
# # ReadTheDocs Documentation
#
# >[Read the Docs](https://readthedocs.org/) 是一款开源的免费软件文档托管平台，它使用 `Sphinx` 文档生成器生成文档。
#
# 本笔记本介绍了如何加载从 `Read-The-Docs` 构建生成的 HTML 内容。
#
# 有关此项目的示例，请参见 [此处](https://github.com/hwchase17/chat-langchain)。
#
# 这假定 HTML 已经被抓取到一个文件夹中。这可以通过取消注释并运行以下命令来完成。

# %%
#!pip install beautifulsoup4

# %%
#!wget -r -A.html -P rtdocs https://langchain.readthedocs.io/en/latest/

# %%
from langchain.document_loaders import ReadTheDocsLoader

# %%
loader = ReadTheDocsLoader("rtdocs", features='html.parser')

# %%
docs = loader.load()
