# %% [markdown]
# # AwaDB
# [AwaDB](https://github.com/awa-ai/awadb) 是一个基于人工智能的数据库，用于搜索和存储LLM应用程序使用的嵌入向量。
# 这个笔记本展示了与AwaDB相关的功能如何使用。

# %%
# !pip install awadb

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import AwaDB
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader('../../../state_of_the_union.txt')
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size= 100, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
db = AwaDB.from_documents(docs)
query = "What did the president say about Ketanji Brown Jackson"
docs = db.similarity_search(query)

# %%
print(docs[0].page_content)

# %% [markdown]
# 而我是在4天前提名巡回上诉法院法官Ketanji Brown Jackson，这是我们国家顶尖的法律智慧之一，她将继续布雷尔大法官的卓越传统。

# %% [markdown]
# ## 相似性搜索和得分

# %% [markdown]
# 返回的距离分数在0-1之间。0表示不相似，1表示最相似。

# %%
docs = db.similarity_search_with_score(query)

# %%
print(docs[0])

# %% [markdown]
# (Document(page_content='而我是在4天前提名巡回上诉法院法官Ketanji Brown Jackson，这是我们国家顶尖的法律智慧之一，她将继续布雷尔大法官的卓越传统。', metadata={'source': '../../../state_of_the_union.txt'}), 0.561813814013747)

# %% [markdown]
# ## 恢复之前创建和添加数据的表

# %%
AwaDB automatically persists added document data

# %% [markdown]
# 如果您可以恢复之前创建和添加的表，只需按照以下步骤操作即可：

# %%
awadb_client = awadb.Client()
ret = awadb_client.Load('langchain_awadb')
if ret : print('awadb load table success')
else:
    print('awadb load table failed')

# %%
awadb load table success
