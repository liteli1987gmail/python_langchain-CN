# %% [markdown]
# # 如何使用 few shot examples
#
# 本笔记本涵盖了如何在聊天模型中使用 few shot examples。
#
# 并没有关于如何最佳使用 few shot prompting 的确定共识。因此，我们尚未固定任何抽象，而是使用现有的抽象。

# %% [markdown]
# ## 人工智能 / 人类消息的交替
# 第一种 few shot prompting 的方法是使用交替的人工智能 / 人类消息。以下是一个示例。

# %%
from langchain.chat_models import ChatOpenAI
from langchain import PromptTemplate, LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

# %%
chat = ChatOpenAI(temperature=0)

# %%
template="You are a helpful assistant that translates english to pirate."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
example_human = HumanMessagePromptTemplate.from_template("Hi")
example_ai = AIMessagePromptTemplate.from_template("Argh me mateys")
human_template="{text}"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, example_human, example_ai, human_message_prompt])
chain = LLMChain(llm=chat, prompt=chat_prompt)
# get a chat completion from the formatted messages
chain.run("I love programming.")
# Out:
# "I be lovin' programmin', me hearty!"

# %% [markdown]
# ## 系统消息
#
# OpenAI 提供了一种可选的 `name` 参数，他们也建议结合系统消息使用 few shot prompting。以下是如何执行的示例。

# %%
template="You are a helpful assistant that translates english to pirate."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
example_human = SystemMessagePromptTemplate.from_template("Hi", additional_kwargs={"name": "example_user"})
example_ai = SystemMessagePromptTemplate.from_template("Argh me mateys", additional_kwargs={"name": "example_assistant"})
human_template="{text}"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, example_human, example_ai, human_message_prompt])
chain = LLMChain(llm=chat, prompt=chat_prompt)
# get a chat completion from the formatted messages
chain.run("I love programming.")
# Out:
# "I be lovin' programmin', me hearty."
