# %% [markdown]
# # Twilio
#
# 本文将介绍如何使用[Twilio API包装器](https://www.twilio.com)发送短信。

# %% [markdown]
# ## 安装
#
# 使用此工具需要安装Python Twilio包 `twilio`

# %%
# !pip install twilio

# %% [markdown]
# 您还需要设置Twilio帐户并获取您的凭据。 您需要您的帐户字符串标识符（SID）和授权令牌。 您还需要一个用于发送消息的数字。
#
# 您可以将这些参数作为命名参数`account_sid`，`auth_token`，`from_number`传递给TwilioAPIWrapper，或者您可以设置环境变量`TWILIO_ACCOUNT_SID`，`TWILIO_AUTH_TOKEN`，`TWILIO_FROM_NUMBER`。

# %% [markdown]
# ## 发送消息

# %%
from langchain.utilities.twilio import TwilioAPIWrapper

# %%
twilio = TwilioAPIWrapper(
#     account_sid="foo",
#     auth_token="bar",
#     from_number="baz,"
)

# %%
twilio.run("hello world", "+16162904619")
