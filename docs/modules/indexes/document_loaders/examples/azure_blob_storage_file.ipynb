# %% [markdown]
# # Azure Blob 存储文件
#
# >[Azure Files](https://learn.microsoft.com/en-us/azure/storage/files/storage-files-introduction) 提供了可通过行业标准 Server Message Block (`SMB`) 协议、网络文件系统 (`NFS`) 协议和 `Azure Files REST API` 访问的在云中完全托管的文件共享。
#
# 这涵盖了如何从 Azure Files 加载文档对象。

# %%
#!pip install azure-storage-blob

# %%
from langchain.document_loaders import AzureBlobStorageFileLoader

# %%
loader = AzureBlobStorageFileLoader(conn_str='<connection string>', container='<container name>', blob_name='<blob name>')

# %%
loader.load()
# Out:
# [Document(page_content='Lorem ipsum dolor sit amet.', lookup_str='', metadata={'source': '/var/folders/y6/8_bzdg295ld6s1_97_12m4lr0000gn/T/tmpxvave6wl/fake.docx'}, lookup_index=0)]
