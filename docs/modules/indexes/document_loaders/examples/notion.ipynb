# %% [markdown]
# ＃ Notion DB 1/2
#
# > [Notion]（https://www.notion.so/）是一个协作平台，具有修改后的Markdown支持，可以集成看板，任务，维基和数据库。 它是一个集注释，知识和数据管理，项目和任务管理于一体的工作区。
#
# 本笔记本介绍了如何从Notion数据库转储中加载文档。
#
# 为了获得此观念转储，请按照以下说明操作：
#
# ## 🧑 有关导入您自己的数据集的说明
#
# 从Notion导出您的数据集。 您可以通过单击右上角的三个点，然后单击“导出”来执行此操作。
#
# 在导出时，请确保选择“Markdown＆CSV”格式选项。
#
# 这将在您的下载文件夹中生成一个“.zip”文件。 将“.zip”文件移动到此存储库中。
#
# 运行以下命令解压缩zip文件（根据需要替换“Export ...”为自己的文件名）。
#
# ```shell
# unzip Export-d3adfe0f-3131-4bf3-8987-a52017fc1bae.zip -d Notion_DB
# ```
#
# 运行以下命令以摄取数据。

# %%
from langchain.document_loaders import NotionDirectoryLoader

# %%
loader = NotionDirectoryLoader("Notion_DB")

# %%
docs = loader.load()
