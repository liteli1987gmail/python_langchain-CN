# %% [markdown]
# # Azure Cognitive Search
#
# >[Azure Cognitive Search](https://learn.microsoft.com/en-us/azure/search/search-what-is-azure-search)（原名为 `Azure Search`）是一种云搜索服务，为开发人员提供基础架构、API 和工具，用于在 Web、移动和企业应用程序中构建丰富的搜索体验，可用于搜索用户拥有的异构内容的搜索引擎。
#
# >搜索是向用户展示文本的应用程序的基础，其中常见的场景包括目录或文档搜索、在线零售应用程序，或用于专有内容的数据探索。当您创建一个搜索服务时，您将使用以下功能：
# >- 实现全文搜索的搜索引擎，包含用户拥有的内容的搜索索引
# >- 丰富的索引，包括词法分析和可选的 AI 增强，用于内容提取和转换
# >- 用于文本搜索、模糊搜索、自动完成、地理搜索等的丰富查询语法
# >- 通过 Azure SDK 中的 REST API 和客户端库进行编程
# >- 在数据层，机器学习层和 AI（认知服务）中进行 Azure 集成
#
# 这个笔记本演示了如何在 LangChain 中使用 Azure Cognitive Search (ACS)。

# %% [markdown]
# ## 设置 Azure Cognitive Search
#
# 要设置 ACS，请按照此处的说明操作：[https://learn.microsoft.com/zh-cn/azure/search/search-create-service-portal]。
#
# 请注意
# 1. 您的 ACS 服务的名称，
# 2. 您的 ACS 索引的名称，
# 3. 您的 API 密钥。
#
# 您的 API 密钥可以是管理员或查询密钥，但由于我们只读取数据，因此建议使用查询密钥。

# %% [markdown]
# ## 使用 Azure Cognitive Search 检索器

# %%
import os

from langchain.retrievers import AzureCognitiveSearchRetriever

# %% [markdown]
# 将服务名称、索引名称和 API 密钥设置为环境变量（或者，您可以将它们作为参数传递给 `AzureCognitiveSearchRetriever`）。

# %%
os.environ["AZURE_COGNITIVE_SEARCH_SERVICE_NAME"] = "<YOUR_ACS_SERVICE_NAME>"
os.environ["AZURE_COGNITIVE_SEARCH_INDEX_NAME"] ="<YOUR_ACS_INDEX_NAME>"
os.environ["AZURE_COGNITIVE_SEARCH_API_KEY"] = "<YOUR_API_KEY>"

# %% [markdown]
# 创建检索器

# %%
retriever = AzureCognitiveSearchRetriever(content_key="content")

# %% [markdown]
# 现在，您可以从 Azure Cognitive Search 中检索文档了

# %%
retriever.get_relevant_documents("what is langchain")
